# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset
IceCream = pd.read_csv('IceCreamData.csv')

# %%
IceCream.head(5)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
IceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
sns.jointplot(x = 'Temperature' , y = 'Revenue', data = IceCream, color = 'green')

# %%
sns.jointplot(x='Revenue' , y= 'Temperature', data = IceCream, color ='Blue')

# %%
sns.pairplot(IceCream)

# %%
sns.lmplot(x = 'Temperature', y = 'Revenue', data = IceCream)

# %%
x = IceCream[['Temperature']]

# %%
x
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
y = IceCream[['Revenue']]

# %%
y
# Out:
#         Revenue
# 0    534.799028
# 1    625.190122
# 2    660.632289
# 3    487.706960
# 4    316.240194
# ..          ...
# 495  524.746364
# 496  755.818399
# 497  306.090719
# 498  566.217304
# 499  655.660388
#
# [500 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#      Temperature
# 249    18.148952
# 433     8.756004
# 19     21.775948
# 322    18.439982
# 332    15.843022
# ..           ...
# 106    23.761436
# 270    24.628611
# 348    38.185199
# 435    15.916678
# 102    14.287196
#
# [400 rows x 1 columns]

# %%
x_train.shape
# Out:
# (400, 1)

# %%
x_test.shape
# Out:
# (100, 1)

# %%
y_train.shape
# Out:
# (400, 1)

# %%
y_train
# Out:
#         Revenue
# 249  473.568112
# 433  246.787161
# 19   534.622865
# 322  463.480508
# 332  379.564268
# ..          ...
# 106  553.445291
# 270  603.305339
# 348  856.303304
# 435  381.043377
# 102  322.592741
#
# [400 rows x 1 columns]

# %%
y_test
# Out:
#         Revenue
# 361  659.873287
# 73   623.248701
# 374  559.135869
# 155  497.752318
# 104  627.901841
# ..          ...
# 347  564.310532
# 86   643.944327
# 75   653.986736
# 438  412.082357
# 15   469.909033
#
# [100 rows x 1 columns]

# %%
y_test.shape
# Out:
# (100, 1)

# %%
#Train the model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m)', regressor.coef_)
print('Linear Model Coefficient (b)', regressor.intercept_)
# Out:
# Linear Model Coefficient (m) [[21.38197386]]
# Linear Model Coefficient (b) [46.80464128]

# %%
#Test the model

# %%
x_test.shape
# Out:
# (100, 1)

# %%
y_predict = regressor.predict(x_test)

# %%
y_predict
# Out:
# array([[681.93870622],
#        [632.14474995],
#        [559.64360486],
#        [498.90609993],
#        [615.45939165],
#        [304.72417213],
#        [285.79420948],
#        [315.60842003],
#        [506.26427154],
#        [685.69744019],
#        [723.96030494],
#        [400.84625166],
#        [431.61634142],
#        [671.36600031],
#        [ 52.51422053],
#        [198.77682819],
#        [523.08595488],
#        [563.90495549],
#        [583.83579144],
#        [682.24517768],
#        [556.2285085 ],
#        [783.88766163],
#        [655.44109362],
#        [570.0735459 ],
#        [912.21841974],
#        [664.74778505],
#        [315.96428407],
#        [631.00983241],
#        [731.1169322 ],
#        [698.02984963],
#        [435.08453949],
#        [471.22058847],
#        [710.29440571],
#        [799.81874771],
#        [641.02153776],
#        [493.66044553],
#        [744.9247237 ],
#        [318.10831232],
#        [262.69083171],
#        [132.04437543],
# ...

# %%
y_test
# Out:
#         Revenue
# 361  659.873287
# 73   623.248701
# 374  559.135869
# 155  497.752318
# 104  627.901841
# ..          ...
# 347  564.310532
# 86   643.944327
# 75   653.986736
# 438  412.082357
# 15   469.909033
#
# [100 rows x 1 columns]

# %%
plt.scatter(x_train,y_train, color = 'grey')
plt.plot(x_train, regressor.predict(x_train), color = 'red')
plt.ylabel('Revenue [Dollars]')
plt.xlabel('Temperature [DegC]')
plt.title('Revenue Generated vs. Temperature @ Ice Cream stand(Trainingnset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @ Ice Cream stand(Trainingnset)')

# %%
plt.scatter(x_test,y_test, color = 'blue')
plt.plot(x_test, regressor.predict(x_test), color = 'black')
plt.ylabel('Revenue [Dollars]')
plt.xlabel('Temperature [DegC]')
plt.title('Revenue Generated vs. Temperature @ Ice Cream stand(Testingset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @ Ice Cream stand(Testingset)')

# %%
T = 40
T = np.asarray(T)
T = np.reshape(T, (-1, 1))
revenue = regressor.predict(T)

# %%
revenue
# Out:
# array([[902.08359549]])
